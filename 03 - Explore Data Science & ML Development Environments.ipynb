# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("dataset.csv")
print(df.head())
# Out:
#    id first_name   last_name                         email     city
# 0   1       Abba     Stallen          astallen0@census.gov      NaN
# 1   2     Moises       Nolot      mnolot1@surveymonkey.com  Banqiao
# 2   3     Jackie  Shackleton  jshackleton2@fastcompany.com      NaN
# 3   4      Rance        John                rjohn3@hud.gov      NaN
# 4   5      Keely  Atte-Stone         kattestone4@issuu.com      NaN

# %%
df.isnull().sum()
# Out:
# id              0
# first_name      0
# last_name       0
# email           0
# city          296
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# id            0
# first_name    0
# last_name     0
# email         0
# city          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 704 entries, 1 to 999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          704 non-null    int64
#  1   first_name  704 non-null    str
#  2   last_name   704 non-null    str
#  3   email       704 non-null    str
#  4   city        704 non-null    str
# dtypes: int64(1), str(4)
# memory usage: 33.0 KB

# %%
from pathlib import Path

output_path = Path("cleaned_data.csv")
df.to_csv(output_path,index=False)
print(f"{output_path.absolute()}")
# Out:
# C:\Users\tohidi\Desktop\ML&AI Engineering\cleaned_data.csv

# %%
output_path.absolute()
# Out:
# WindowsPath('C:/Users/tohidi/Desktop/ML&AI Engineering/cleaned_data.csv')

# %%
Path().absolute()
# Out:
# WindowsPath('C:/Users/tohidi/Desktop/ML&AI Engineering')
